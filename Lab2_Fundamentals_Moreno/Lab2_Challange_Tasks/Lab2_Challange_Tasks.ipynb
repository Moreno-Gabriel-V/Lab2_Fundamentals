# %%
target_name = "M8R8N8"
SEED_NUM = 8
sample_name = ""

for char in target_name:
    if char in "Teto":
        sample_name = SEED_NUM
    else:
        sample_name = char

print(f"Execution Log: proccessing {target_name}...")
print(f"Sample Output: {sample_name}")
# Out:
# Execution Log: proccessing M8R8N8...
# Sample Output: 8

# %%
first_letter = "M"
ASCII_val = ord(first_letter)
seed_num = 1
loops = 5

verification_hash = (ASCII_val + seed_num) - loops

print(f"ASCII: {ASCII_val}, Hash: {verification_hash}")
# Out:
# ASCII: 77, Hash: 73

# %%
correct_password = "HELLO_WORLD.exe"
attempts = 0
user_input = ""

while user_input != correct_password:
    user_input = input("Enter password: ")
    attempts += 1
    print(f"Attempt {attempts}: You said '{user_input}' [insert bad jokes here]")

    
print(f"Access Granted in {attempts} attempts. Good =job!")
# Out:
# Attempt 1: You said 'a; [insert bad jokes here]
# Attempt 2: You said 's; [insert bad jokes here]
# Attempt 3: You said 'd; [insert bad jokes here]
# Attempt 4: You said 'f; [insert bad jokes here]
# Attempt 5: You said 'g; [insert bad jokes here]
# Attempt 6: You said 'HELLO_WORLD.exe; [insert bad jokes here]
# Access Granted in 6 attempts
